# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
    }

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %% [markdown]
# BASIC OPERATIONS

# %%
print(df.head())
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %% [markdown]
# print(df.head()) prints Top 5 rows in the data

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %% [markdown]
# print(df.columns) prints all the columns in the data

# %%
print(df.describe())
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
print(df.Name)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
print(df.Age)
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
print(df[df['Age']>28])
# Out:
#       Name  Age    City
# 1      Bob   30  London
# 2  Charlie   35   Paris

# %% [markdown]
# print(df[df['Age']>28]) prints all the entries which has the value in the age column greater than 28

# %% [markdown]
# Data is changed. Its no longer hardcoded like in line 1. We're using a csv file

# %%
df = pd.read_csv('people.csv')

# %% [markdown]
# pd.read_csv('filename.csv') reads a new file and links it with the dataframe.

# %%
print(df.head())
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    Diana   28    Berlin
# 4    Ethan   40    Sydney

# %%
print(df.tail())
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    Diana   28    Berlin
# 4    Ethan   40    Sydney

# %% [markdown]
# Prints last five rows

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %% [markdown]
# Prints the details, structure of the data

# %%
print(df.describe())
# Out:
#             Age
# count   5.00000
# mean   31.60000
# std     5.94138
# min    25.00000
# 25%    28.00000
# 50%    30.00000
# 75%    35.00000
# max    40.00000

# %%
print(df['City'])
# Out:
# 0    New York
# 1      London
# 2       Paris
# 3      Berlin
# 4      Sydney
# Name: City, dtype: object

# %%
print(df[df['City'] == 'London'])
# Out:
#   Name  Age    City
# 1  Bob   30  London
